# %% [markdown]
# # Exploratory Data Analysis: Mammography BIRADS Classification
#
# This notebook explores the dataset structure, visualizes distributions, and prepares data for modeling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

plt.style.use('default')
sns.set_style('whitegrid')

# %% [markdown]
# ## Dataset Overview

# %%
# Load dataset
# Adjust path as needed
print('Dataset loading and exploration...')
print(f'Project: {project_name}')
print(f'Model Type: {project_info["model_type"]}')

# %% [markdown]
# ## Data Statistics

# %%
# Calculate and display statistics
print('Data statistics will be displayed here...')

# %% [markdown]
# ## Visualizations

# %%
# Create visualizations
print('Visualizations will be generated here...')
